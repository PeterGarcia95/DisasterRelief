# %%
import pandas as pd

# %%
df=pd.read_csv('./clean_tweets.csv').drop(columns='Unnamed: 0')

# %%
df
# Out:
#             username                                               text  \
# 0     Amithridya1001  No update or action on supply issue at near 2 ...
# 1        ellensweeps  I live in what is considered the largest conce...
# 2            CoxHelp  No, there is not an outage and your modem is r...
# 3       Steven_McKie  No big deal @Xfinity I didn’t have to work tod...
# 4            Larapic  So we filled the Adpt with post-its today and ...
# ...              ...                                                ...
# 1486   Abraham_lugol                                           Vas mija
# 1487    infidusfiles  @VerizonSupport no I don't. And there isn't a ...
# 1488       tikieDoll        No work because of a power outage ...sweet
# 1489     DanLHughes1  “Either you run the day or the day runs you.” ...
# 1490        SandyAlz  http://Amazon.com : Mike & Me: The New Alzheim...
#
#            label       dates  \
# 0         outage  2019-07-23
# 1         outage  2019-07-23
# ...
