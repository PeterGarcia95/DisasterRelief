# %% [markdown]
# # Cleaning Tweets

# %% [markdown]
# ## Table of Contents
# 1. [Imports](#imports)
# 2. [Importing Data](#data)
# 3. [Extracting Alphanumeric Tokens](#tokens)
# 4. [Filtering by Severe Weather in Massachusetts](#mass)
# 5. [Fixing Class Imbalance - Bootstrapping](#imbalance)
# 6. [Simulating Random Boston Coordinates](#coordinates)

# %% [markdown]
# <a id = imports ></a>
# ## Imports

# %%
import pandas as pd
import random
import numpy as np
import regex as re
import nltk
from bs4 import BeautifulSoup

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <a id = data ></a>
# ## Importing Data

# %%
df = pd.read_csv('../datasets/raw_data/raw_tweets.csv')
df
# Out:
#                              username  \
# 0                     Julie Wilcox WX
# 1                           Hays Wood
# 2      Ed Vallee | Empire Weather LLC
# 3                      Joselin Sundin
# 4                    Shelley Woodroof
# ...                               ...
# 11460                            Niru
# 11461                            Sean
# 11462                   Heather Rollo
# 11463                          Junior
# 11464                            Ivan
#
#                                                     text                 date
# 0      An emergency manager once explained it this wa...  2019-08-31 20:22:16
# 1      @Xfinity get your shit together! First college...  2019-08-31 17:54:07
# 2      Have had many ask me what to do for prep. Here...  2019-08-31 15:50:58
# 3      @RogersHelps - GM, is any outage in the Duffer...  2019-08-31 14:28:14
# 4      Solar lights that people use outside to light ...  2019-08-31 10:45:32
# ...                                                  ...                  ...
# 11460  With the power outage, and no WiFi I feel like...  2014-01-03 04:58:08
# 11461  .@SawneeEMC No one would answer the damn phone...  2014-01-03 03:55:06
# 11462  This is such a huge power outage.... and no st...  2014-01-02 21:16:41
# 11463  Thank you power outage for no work till who kn...  2014-01-01 19:00:06
# 11464  There was a power outage at work today, so now...  2014-01-01 00:50:59
#
# [11465 rows x 3 columns]

# %% [markdown]
# Changing the date of the tweet was posted to just the date:

# %%
df['date'] = pd.to_datetime(df['date']).dt.date

# %%
df.head()
# Out:
#                          username  \
# 0                 Julie Wilcox WX
# 1                       Hays Wood
# 2  Ed Vallee | Empire Weather LLC
# 3                  Joselin Sundin
# 4                Shelley Woodroof
#
#                                                 text        date
# 0  An emergency manager once explained it this wa...  2019-08-31
# 1  @Xfinity get your shit together! First college...  2019-08-31
# 2  Have had many ask me what to do for prep. Here...  2019-08-31
# 3  @RogersHelps - GM, is any outage in the Duffer...  2019-08-31
# 4  Solar lights that people use outside to light ...  2019-08-31

# %%
df.shape
# Out:
# (11465, 3)

# %%
df.dtypes
# Out:
# username    object
# text        object
# date        object
# dtype: object

# %% [markdown]
# Looking for Nulls

# %%
df.isnull().sum()
# Out:
# username     3
# text         7
# date        11
# dtype: int64

# %% [markdown]
# Need to drop Nulls or Regix will crash

# %%
df.dropna(how='any',inplace=True)

# %%
df.shape
# Out:
# (11451, 3)

# %%
df.isnull().sum()
# Out:
# username    0
# text        0
# date        0
# dtype: int64

# %% [markdown]
# <a id = tokens ></a>
# ## Extracting Alphanumeric Tokens

# %%
stopwords = nltk.corpus.stopwords.words('english')

# %%
def tweet_cleaning(raw_tweet):
    
    # 1. Remove punctuation
    letters_numbers_only = re.sub('[^A-Za-z0-9]+', " ", raw_tweet)
    
    
    # 2. Convert to lower case, split into individual words.
    words = letters_numbers_only.lower().split()
    
    # 3. Stopwords
    stops = set(stopwords)
    
    # 4. Search Stopwords
    meaningful_words = [w for w in words if not w in stops]
    
    # 5. Join 
    return(" ".join(meaningful_words))

# %%
# Tweet Count
total_tweets = len(df)
print(f'There are {total_tweets} tweets.')


# List holders
clean_tweets = []

#Running the functions
print("Cleaning and parsing tweets...")

j = 0
for text in df['text']:
    # Join clean tweets
    clean_tweets.append(tweet_cleaning(text))
    
    # Message to keep track
    if (j + 1) % 1_000 == 0:
        print(f'Tweet {j + 1} of {total_tweets}.')
    
    j += 1

print("COMPLETE")
# Out:
# There are 11451 tweets.
# Cleaning and parsing tweets...
# Tweet 1000 of 11451.
# Tweet 2000 of 11451.
# Tweet 3000 of 11451.
# Tweet 4000 of 11451.
# Tweet 5000 of 11451.
# Tweet 6000 of 11451.
# Tweet 7000 of 11451.
# Tweet 8000 of 11451.
# Tweet 9000 of 11451.
# Tweet 10000 of 11451.
# Tweet 11000 of 11451.
# COMPLETE

# %%
df['clean_text'] = clean_tweets

# %%
df
# Out:
#                              username  \
# 0                     Julie Wilcox WX
# 1                           Hays Wood
# 2      Ed Vallee | Empire Weather LLC
# 3                      Joselin Sundin
# 4                    Shelley Woodroof
# ...                               ...
# 11460                            Niru
# 11461                            Sean
# 11462                   Heather Rollo
# 11463                          Junior
# 11464                            Ivan
#
#                                                     text        date  \
# 0      An emergency manager once explained it this wa...  2019-08-31
# 1      @Xfinity get your shit together! First college...  2019-08-31
# 2      Have had many ask me what to do for prep. Here...  2019-08-31
# 3      @RogersHelps - GM, is any outage in the Duffer...  2019-08-31
# 4      Solar lights that people use outside to light ...  2019-08-31
# ...                                                  ...         ...
# 11460  With the power outage, and no WiFi I feel like...  2014-01-03
# 11461  .@SawneeEMC No one would answer the damn phone...  2014-01-03
# 11462  This is such a huge power outage.... and no st...  2014-01-02
# 11463  Thank you power outage for no work till who kn...  2014-01-01
# 11464  There was a power outage at work today, so now...  2014-01-01
#
#                                               clean_text
# 0      emergency manager explained way interview imag...
# 1      xfinity get shit together first college footba...
# 2      many ask prep done orlando fl reference water ...
# 3      rogershelps gm outage dufferin queen area sinc...
# 4      solar lights people use outside light pathways...
# ...                                                  ...
# 11460      power outage wifi feel like didnt work school
# 11461  sawneeemc one would answer damn phone submit o...
# 11462                  huge power outage stoplights work
# 11463  thank power outage work till knows pic twitter...
# 11464  power outage work today get tip money means ch...
#
# [11451 rows x 4 columns]

# %% [markdown]
# <a id = mass ></a>
# ## Filtering by Severe Weather in Massachusetts

# %%
targets = pd.read_csv('../datasets/outages_since_2014.csv')

# %%
targets.head()
# Out:
#   Date Event Began Time Event Began Date of Restoration Time of Restoration  \
# 0       10/22/2014         10:46 PM          10/22/2014            10:47 PM
# 1        6/23/2015          6:30 PM           6/24/2015             5:00 AM
# 2         8/4/2015          7:17 AM            8/5/2015            12:52 PM
# 3        7/22/2016         11:50 PM           7/23/2016             9:10 AM
# 4        7/23/2016          7:30 PM           7/24/2016             7:30 AM
#
#                                        Area Affected NERC Region  \
# 0  New Hampshire, Maine, Massachusetts, Rhode Isl...        NPCC
# 1  Connecticut, Maine, Massachusetts, New Hampshi...        NPCC
# 2                       Massachusetts: Rhode Island:        NPCC
# 3  Massachusetts: Connecticut: Rhode Island: New ...        NPCC
# 4  Connecticut: Massachusetts: New Hampshire: Ver...        NPCC
#
#        Event Type Number of Customers Affected  \
# 0  Severe Weather                       66,650
# 1  Severe Weather                       62,442
# 2  Severe Weather                      132,000
# 3  Severe Weather                        57058
# 4  Severe Weather                       101073
#
#                                       Alert Criteria
# 0                                                NaN
# 1  Loss of electric service to more than 50,000 c...
# 2  Loss of electric service to more than 50,000 c...
# 3  Loss of electric service to more than 50,000 c...
# 4  Loss of electric service to more than 50,000 c...

# %%
targets.dtypes
# Out:
# Date Event Began                object
# Time Event Began                object
# Date of Restoration             object
# Time of Restoration             object
# Area Affected                   object
# NERC Region                     object
# Event Type                      object
# Number of Customers Affected    object
# Alert Criteria                  object
# dtype: object

# %%
targets['Date Event Began'] = pd.to_datetime(targets['Date Event Began']).dt.date

# %%
targets['Date of Restoration'] = pd.to_datetime(targets['Date of Restoration']).dt.date

# %%
targets
# Out:
#    Date Event Began Time Event Began Date of Restoration Time of Restoration  \
# 0        2014-10-22         10:46 PM          2014-10-22            10:47 PM
# 1        2015-06-23          6:30 PM          2015-06-24             5:00 AM
# 2        2015-08-04          7:17 AM          2015-08-05            12:52 PM
# 3        2016-07-22         11:50 PM          2016-07-23             9:10 AM
# 4        2016-07-23          7:30 PM          2016-07-24             7:30 AM
# 5        2016-09-11         12:05 PM          2016-09-11             3:10 PM
# 6        2017-02-09          4:05 PM          2017-02-10             5:15 AM
# 7        2017-03-02         12:20 PM          2017-03-02            11:45 PM
# 8        2017-10-29         11:40 PM          2017-11-01             6:08 PM
# 9        2018-03-02          1:51 PM          2018-03-05             1:18 PM
# 10       2018-03-07          7:37 PM          2018-03-10             4:35 PM
# 11       2018-03-13          8:50 AM          2018-03-14            11:22 PM
# 12       2018-04-05         12:50 AM          2018-04-05             4:00 PM
# 13       2018-05-15          6:35 PM          2018-05-18             3:57 PM
# 14       2018-06-18          6:20 PM          2018-06-19            12:15 AM
# 15       2018-10-16          4:15 AM          2018-10-16             5:11 PM
# 16       2018-11-03          5:20 PM          2018-11-04             2:30 PM
# 17       2019-02-25          1:35 PM          2019-02-26             2:50 AM
# 18       2019-07-23          3:39 PM          2019-07-23             7:00 PM
#
#                                         Area Affected NERC Region  \
# 0   New Hampshire, Maine, Massachusetts, Rhode Isl...        NPCC
# 1   Connecticut, Maine, Massachusetts, New Hampshi...        NPCC
# 2                        Massachusetts: Rhode Island:        NPCC
# 3   Massachusetts: Connecticut: Rhode Island: New ...        NPCC
# 4   Connecticut: Massachusetts: New Hampshire: Ver...        NPCC
# 5   Connecticut: Massachusetts: New Hampshire: Rho...        NPCC
# 6           Connecticut: Massachusetts: Rhode Island:        NPCC
# 7   Connecticut: Maine: Massachusetts: New Hampshi...        NPCC
# 8   Connecticut: Massachusetts: New Hampshire: Mai...        NPCC
# 9           Connecticut: Massachusetts: Rhode Island:        NPCC
# 10  Connecticut: Massachusetts: Maine: New Hampshi...        NPCC
# 11                       Massachusetts: Rhode Island:        NPCC
# 12  Connecticut: Maine: Massachusetts: New Hampshi...        NPCC
# 13          Connecticut: Massachusetts: Rhode Island:        NPCC
# 14  Connecticut: Maine: Massachusetts: New Hampshi...        NPCC
# 15  Connecticut: Rhode Island: Massachusetts: Verm...        NPCC
# 16  Connecticut: Massachusetts: New Hampshire: Ver...        NPCC
# 17  Connecticut, Massachusetts, New Hampshire, Mai...        NPCC
# 18                                     Massachusetts:        NPCC
#
#         Event Type Number of Customers Affected  \
# 0   Severe Weather                       66,650
# 1   Severe Weather                       62,442
# 2   Severe Weather                      132,000
# 3   Severe Weather                        57058
# 4   Severe Weather                       101073
# 5   Severe Weather                        57960
# 6   Severe Weather                        11525
# 7   Severe Weather                        54316
# 8   Severe Weather                       310453
# 9   Severe Weather                       325000
# 10  Severe Weather                       102000
# 11  Severe Weather                       123629
# 12  Severe Weather                        65932
# 13  Severe Weather                       120000
# 14  Severe Weather                       112927
# 15  Severe Weather                        18000
# 16  Severe Weather                        62000
# 17  Severe Weather                        72332
# 18  Severe Weather                        54535
#
#                                        Alert Criteria
# 0                                                 NaN
# 1   Loss of electric service to more than 50,000 c...
# 2   Loss of electric service to more than 50,000 c...
# 3   Loss of electric service to more than 50,000 c...
# 4   Loss of electric service to more than 50,000 c...
# 5   Loss of electric service to more than 50,000 c...
# 6   Loss of electric service to more than 50,000 c...
# 7   Loss of electric service to more than 50,000 c...
# 8   Loss of electric service to more than 50,000 c...
# 9   Loss of electric service to more than 50,000 c...
# 10  Loss of electric service to more than 50,000 c...
# 11  Loss of electric service to more than 50,000 c...
# 12  Loss of electric service to more than 50,000 c...
# 13  Loss of electric service to more than 50,000 c...
# 14  Loss of electric service to more than 50,000 c...
# 15  Loss of electric service to more than 50,000 c...
# 16  Loss of electric service to more than 50,000 c...
# 17  Loss of electric service to more than 50,000 c...
# 18  Loss of electric service to more than 50,000 c...

# %%
#Each value in the nested list is a date that the blackout occured
blackouts = [pd.date_range(start = targets.loc[i ,'Date Event Began'], end = targets.loc[i, 'Date of Restoration'])for i in targets.index]

# Flatten the 2d list to 1d
# https://www.geeksforgeeks.org/python-ways-to-flatten-a-2d-list/
blackouts = [j for sub in blackouts for j in sub]

# Number of tweets that occured during an actual blackout
df['date'].isin(blackouts).sum()

df['target'] = df['date'].isin(blackouts)
df['target'] *= 1

# %%
# blackouts

# %%
df.target.sum()
# Out:
# 59

# %%
df[df.target == 1]
# Out:
#                      username  \
# 4016        Waldemar Gonzalez
# 4017                oldschool
# 4018                   Deanna
# 4019                     Rose
# 4020             LocoMoco Guy
# 4021                      Ash
# 4022          Scott Yergensen
# 4023  PA Department of Health
# 4024                 pdmeyers
# 4025                  mrsbb10
# 4026                BlaQ Czar
# 4027                SkellBell
# 4028                Bob Kelly
# 4029                       MM
# 4030                   Mufasa
# 4031                    alice
# 4032                    alice
# 4033             Peter Eacmen
# 4034             Ed McDonough
# 4051             Brandon Kopp
# 4052         Richard Balducci
# 4053          The Colonel 100
# 4054         Stephani Shelton
# 4055          Kimmy Schweizer
# 4056                    Julia
# 4057              Court Bauer
# 4058              C. Peterson
# 4059          Colleen Krieger
# 4060                     erin
# 4061                 J.BAY671
# 4062            мι¢нєℓℓєℓуииє
# 4063              katherine p
# 4064                      Tim
# 4065           Jason Ashworth
# 4066               Dan Opallo
# 4067      woke bae tim burton
# 4068                    Tammy
# 4069              xxnike629xx
# 4070               kate watts
# 4071                     LODE
# 4072              Call Me Vee
# 4073            Robert Notari
# 4074      Michael D Nothstein
# 4075                 Vernetta
# 4076                Elizabeth
# 4077        Madam Moon Shadow
# 4078        rebeccadrives.com
# 4079             Tiffany Arey
# 4080                  Claudia
# 8648                   Trilla
# 8649               Mike Chmie
# 8650            Sarah Peduzzi
# 8651              lobsterfest
# 8652              lobsterfest
# 8653       ET School District
# 8654                    Steph
# 8655              Jade Dragon
# 8656                     Rice
# 8657            Justin Morgan
#
#                                                    text        date  \
# 4016  No work for a week due to power outage, trip t...  2018-03-05
# 4017  Really. !!  NYSEG needs leadership. Is this yo...  2018-03-05
# 4018  Aaaand they left without doing anything. The o...  2018-03-05
# 4019  Power Outage waste: \n  school cafeteria where...  2018-03-05
# 4020  Tried calling the toll free number. No chance ...  2018-03-05
# 4021  No work again today because of the power outag...  2018-03-05
# 4022  Social media may not normally be a support too...  2018-03-05
# 4023  Has your power has been out because of the #no...  2018-03-05
# 4024  Power outage day 4 at work. No work so at home...  2018-03-05
# 4025  @DomEnergyVA day 4 no power! Full fridge/freez...  2018-03-05
# 4026  Lol i walk into work expecting a smooth as day...  2018-03-05
# 4027  Tree crews & line peeps r busting their keeste...  2018-03-05
# 4028  Who can relate??   Power outage for parents me...  2018-03-05
# 4029  County power outage, hurricane force winds,  a...  2018-03-05
# 4030  @aedcelectricity Good morning. Since Saturday ...  2018-03-05
# 4031  Wow so you close school on Friday when there i...  2018-03-05
# 4032  Wow so you close school on Friday when there i...  2018-03-05
# 4033  Hmm this advice two days after outage is usele...  2018-03-05
# 4034  This is from our counterparts in Massachusetts...  2018-03-05
# 4051  @PepcoConnect If you want some low-hanging fru...  2018-03-03
# 4052  @MyBGE third major outage in our neighborhood ...  2018-03-03
# 4053  I think it’s safe to say if I got caught in a ...  2018-03-03
# 4054  @JCP_L @ABC7NY @News12NJ  this link does not w...  2018-03-03
# 4055  Are you still updating outage maps? I see no c...  2018-03-03
# 4056  @verizon @VerizonSupport  any updates on outag...  2018-03-03
# 4057  .@ConEdison has done a deplorable job. Check t...  2018-03-03
# 4058  Thanks for the hard work! It's much appreciate...  2018-03-03
# 4059  @VerizonSupport is there a Fios outage in Wash...  2018-03-03
# 4060  yesterday was senior skip day & I didn’t go to...  2018-03-03
# 4061  @comcastcares I work for a powerful Corp law f...  2018-03-03
# 4062  Well no work again tonight due to power outage...  2018-03-03
# 4063  @MyBGE your outage website is the worst - chec...  2018-03-03
# 4064  @DomEnergyVA wondering why an outage would say...  2018-03-03
# 4065  Screw how cold it is in my house, no lights, f...  2018-03-03
# 4066  Where’d you go AC?!? We were doing great there...  2018-03-03
# 4067  I'm so irritated cuz they were like "ok work S...  2018-03-03
# 4068  No power since 12 yesterday but neighbors powe...  2018-03-03
# 4069  @PPLElectric We haven’t had power in the 17110...  2018-03-03
# 4070  Thanks for your quick reply but it’s not parti...  2018-03-03
# 4071  27 hours and still no power @DomEnergyVA It's ...  2018-03-03
# 4072  I didn’t realize there was even an outage unti...  2018-03-03
# 4073  @VZWSupport When’s my phone going to work agai...  2018-03-03
# 4074  After power outage, re cycling modem does no t...  2018-03-03
# 4075  I’m so mad that people with @verizonfios has c...  2018-03-03
# 4076  @NOVEC I am having a hard time reporting an ou...  2018-03-03
# 4077  Power outage update: Still no power. Sitting i...  2018-03-03
# 4078  This system doesn't work. I've reported my out...  2018-03-03
# 4079  The outage I reported in Schwenksville at Tang...  2018-03-03
# 4080  @gowave_g  Is there a network outage?  No inte...  2018-03-03
# 8648  Power outage can't do no work and can't leave ...  2015-06-23
# 8649  Minute 12 of Power Outage: Limited means to ma...  2015-06-23
# 8650  Power outage at work. No internet. I literally...  2015-06-23
# 8651  @comcastcares cannot connect xfinity TV. Tried...  2015-06-23
# 8652  @comcast cares cannot connect xfinity TV. Trie...  2015-06-23
# 8653  Due to a power outage, there will be no Summer...  2015-06-23
# 8654  Just got the text from my boss saying 'no work...  2015-06-23
# 8655  @chibiokamiddr also wanna make sure no power o...  2015-06-23
# 8656  Power outage at work and I don't have to be th...  2015-06-23
# 8657  @ATT Is there an LTE outage in 61822? I’ve bee...  2015-06-23
#
#                                              clean_text  target
# 4016  work week due power outage trip miami sounds l...       1
# 4017  really nyseg needs leadership first power outa...       1
# 4018  aaaand left without anything outage map longer...       1
# 4019  power outage waste school cafeteria line dance...       1
# 4020  tried calling toll free number chance talk liv...       1
# 4021  work today power outage streaming earlier tonight       1
# 4022  social media may normally support tool apprive...       1
# 4023  power noreaster food fridge safe long power 4 ...       1
# 4024  power outage day 4 work work home painting pro...       1
# 4025  domenergyva day 4 power full fridge freezer sp...       1
# 4026  lol walk work expecting smooth day nope intern...       1
# 4027  tree crews line peeps r busting keesters much ...       1
# 4028  relate power outage parents means heat food lo...       1
# 4029  county power outage hurricane force winds 40 d...       1
# 4030  aedcelectricity good morning since saturday mo...       1
# 4031  wow close school friday risk power outage actu...       1
# 4032  wow close school friday risk power outage actu...       1
# 4033  hmm advice two days outage useless stop tweeti...       1
# 4034  counterparts massachusetts good tips sbout foo...       1
# 4051  pepcoconnect want low hanging fruit work overn...       1
# 4052  mybge third major outage neighborhood lose foo...       1
# 4053  think safe say got caught power outage heat wa...       1
# 4054  jcp l abc7ny news12nj link work added lack inf...       1
# 4055  still updating outage maps see changes please ...       1
# 4056  verizon verizonsupport updates outages south s...       1
# 4057  conedison done deplorable job check replies on...       1
# 4058  thanks hard work much appreciated understand p...       1
# 4059  verizonsupport fios outage washington dc inter...       1
# 4060  yesterday senior skip day go school got text s...       1
# 4061  comcastcares work powerful corp law firm want ...       1
# 4062  well work tonight due power outage ugh paychec...       1
# 4063  mybge outage website worst check status ridicu...       1
# 4064  domenergyva wondering outage would say crew di...       1
# 4065  screw cold house lights food spoiling fridge f...       1
# 4066  go ac great ask estimate great picture downed ...       1
# 4067  irritated cuz like ok work saturday 9 1 extra ...       1
# 4068  power since 12 yesterday neighbors power freez...       1
# 4069  pplelectric power 17110 area since yesterday m...       1
# 4070  thanks quick reply particularly helpful checki...       1
# 4071  27 hours still power domenergyva freezing outa...       1
# 4072   realize even outage got work everyone power home       1
# 4073  vzwsupport phone going work part outage pa ide...       1
# 4074  power outage cycling modem work issue end happ...       1
# 4075  mad people verizonfios cable internet area us ...       1
# 4076  novec hard time reporting outage elderly perso...       1
# 4077  power outage update still power sitting car ch...       1
# 4078  system work reported outage twice get replies ...       1
# 4079  outage reported schwenksville tanglewood drive...       1
# 4080  gowave g network outage internet hours even di...       1
# 8648         power outage work leave free overtime take       1
# 8649  minute 12 power outage limited means make food...       1
# 8650  power outage work internet literally serve pur...       1
# 8651  comcastcares cannot connect xfinity tv tried t...       1
# 8652  comcast cares cannot connect xfinity tv tried ...       1
# 8653  due power outage summer school today students ...       1
# 8654  got text boss saying work power outage place b...       1
# 8655  chibiokamiddr also wanna make sure power outag...       1
# 8656       power outage work thank god longer graveyard       1
# 8657  att lte outage 61822 getting service since got...       1

# %% [markdown]
# <a id = imbalance ></a>
# ## Fixing Class Imbalance - Bootstrapping

# %%
#Undersample majority class
fakenews = df[df['target'] == 0]
fakenews_subset = fakenews.sample(n = 1000, random_state=42)
fakenews_subset

final_df = pd.concat([df[df['target'] == 1], fakenews_subset], axis = 0)
final_df.shape
# Out:
# (1059, 5)

# %%
final_df.shape[0]
# Out:
# 1059

# %% [markdown]
# <a id = coordinates ></a>
# ## Simulating Random Boston Coordinates

# %%
np.random.seed(42)

# %%
#latitude
coor_lat=range(42229077, 42397652)
latitudes=np.random.choice(coor_lat, size=final_df.shape[0])
latitudes=latitudes/1000000

# %%
#longitude
coor_long=range(-71203220, -70987133)
longitude=np.random.choice(coor_long, size=final_df.shape[0])
longitude=longitude/1000000

# %%
final_df['lat']=latitudes
final_df['long']=longitude

# %%
final_df.head()
# Out:
#                username                                               text  \
# 4016  Waldemar Gonzalez  No work for a week due to power outage, trip t...
# 4017          oldschool  Really. !!  NYSEG needs leadership. Is this yo...
# 4018             Deanna  Aaaand they left without doing anything. The o...
# 4019               Rose  Power Outage waste: \n  school cafeteria where...
# 4020       LocoMoco Guy  Tried calling the toll free number. No chance ...
#
#             date                                         clean_text  target  \
# 4016  2018-03-05  work week due power outage trip miami sounds l...       1
# 4017  2018-03-05  really nyseg needs leadership first power outa...       1
# 4018  2018-03-05  aaaand left without anything outage map longer...       1
# 4019  2018-03-05  power outage waste school cafeteria line dance...       1
# 4020  2018-03-05  tried calling toll free number chance talk liv...       1
#
#             lat       long
# 4016  42.351035 -71.098957
# 4017  42.375944 -71.203094
# 4018  42.361009 -71.150891
# 4019  42.332771 -71.175588
# 4020  42.348956 -71.006838

# %%
final_df.to_csv('../datasets/clean_tweets.csv', index = False)
