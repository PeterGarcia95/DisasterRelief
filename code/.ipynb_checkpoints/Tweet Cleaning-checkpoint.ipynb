# %% [markdown]
# # Cleaning Tweets

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import regex as re
import nltk
from bs4 import BeautifulSoup

# %%
file_name_outages='../datasets/raw_tweets.csv'
file_name_random='../datasets/irrelevent_tweets.csv'

# %% [markdown]
# ### DataFrame Set Up

# %%
df1=pd.read_csv(file_name_outages).drop(columns='Unnamed: 0')
df1['label']='outage'
df2=pd.read_csv(file_name_random).drop(columns='Unnamed: 0')
df2['label']='irrelevant'

# %%
df=pd.concat([df1,df2],axis=0)

# %%
df['dates']=pd.to_datetime(df.date).dt.date

# %%
df['dates']=pd.to_datetime(df.dates)

# %%
df.dtypes
# Out:
# username            object
# text                object
# date                object
# label               object
# dates       datetime64[ns]
# dtype: object

# %%
df=df.drop(columns=['date'])

# %%
df.head()
# Out:
#         username                                               text   label  \
# 0  JulieWilcoxWX  An emergency manager once explained it this wa...  outage
# 1      hays_wood  @Xfinity get your shit together! First college...  outage
# 2     EdValleeWx  Have had many ask me what to do for prep. Here...  outage
# 3     teamworkf1  @RogersHelps - GM, is any outage in the Duffer...  outage
# 4     shellz_woo  Solar lights that people use outside to light ...  outage
#
#        dates
# 0 2019-08-31
# 1 2019-08-31
# 2 2019-08-31
# 3 2019-08-31
# 4 2019-08-31

# %%
df.dropna(how='any',inplace=True)

# %% [markdown]
# ### Removing Stop Words and HTML

# %%
stopwords = nltk.corpus.stopwords.words('english')

# %%
def tweet_cleaning(raw_tweet):
    
    # 1. Remove HTML
    tweet_text = BeautifulSoup(raw_tweet).get_text()
    
    # 2. Remove punctuation, keep numbers with 1-4 digits
    letters_numbers_only = re.sub("[^a-zA-Z]", " ", tweet_text)
    latin = re.sub("r'[^\p{Latin}]'", " ", letters_numbers_only)
    
    # 3. Convert to lower case, split into individual words.
    words = latin.lower().split()
    
    # 4. Search
    stops = set(stopwords)
    
    # 5. Stop Words
    meaningful_words = [w for w in words if not w in stops]
    
    # 6. Join 
    return(" ".join(meaningful_words))

# %%
# Tweet Count
total_tweets = df.shape[0]
print(f'There are {total_tweets} tweets.')

# List holders
clean_train_tweets = []
clean_test_tweets = []
# Out:
# There are 61263 tweets.

# %%
#Running the functions
print("Cleaning and parsing the training set movie reviews...")

j = 0
for train_tweet in df['text']:
    # Join clean reviews
    clean_train_tweets.append(tweet_cleaning(train_tweet))
    
    # Message to keep track
    if (j + 1) % 1000 == 0:
        print(f'Tweet {j + 1} of {total_tweets}.')
    
    j += 1

print("Cleaning and parsing the testing set ...")
# Out:
# Cleaning and parsing the training set movie reviews...
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# Tweet 1000 of 61263.
# Tweet 2000 of 61263.
# Tweet 3000 of 61263.
# Tweet 4000 of 61263.
# Tweet 5000 of 61263.
# Tweet 6000 of 61263.
# Tweet 7000 of 61263.
# Tweet 8000 of 61263.
# Tweet 9000 of 61263.
# Tweet 10000 of 61263.
# Tweet 11000 of 61263.
# Tweet 12000 of 61263.
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/1315217853/posts/10215342226611643/ …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/story.php?story_fbid=10220372157880470&id=1425881753 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://curiouscat.me/Mafalda_oliveira …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/belen.deyssig/posts/10219805117661383 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://s.callapp.com/pages/twitter_card.html …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/liennguyen1003/posts/370510000543487 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/bani_mari/status/1167888633656836099 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://soundcloud.com/momen-ha-py/yara-ma-baaref-2014 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.baseballamerica.com/stories/2019-cape-cod-league-top-prospects-31-50/ …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/100000179187571/posts/3003120853037191/ …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/justinbieber/status/1167928341971623937 …pic.twitter.com/3Z1RBvspap" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/100000199896052/posts/3229583330391632/ …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/DJDaleLafayette/posts/10212462737722313 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/603964015/posts/10156632630994016/ …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.youtube.com/channel/UCFuapw4OH7ENhmch20fd1lQ …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/story.php?story_fbid=10157503721372520&id=762627519 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/romereyes26/status/1167910329830932482 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/pathy_ngy/status/1167760692147052544 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/story.php?story_fbid=1287739098051285&id=100004456206072 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/GeorgeRussell63/status/1167850322011860998 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/mbrandtsam/posts/2579719322049531 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/mylesav3ry/status/1167949680690356225 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/663910754/posts/10156173928320755/ …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.pscp.tv/w/cDsBfzEyNjA3MDQyfDF5b0pNek5ScmtkeFEUG9DFQJIexpMiRARzpHUSsfw0ks1rUSIgabi8k62jqA== …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/runrunblue/status/1167933818692493323?s=21 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/leandroruschel/status/1167532160342994945 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/100002382636329/posts/2378391172250281/ …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# Tweet 13000 of 61263.
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/pattyrodriguez/status/1167917238898188290 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/i/status/1167583588600205313 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/100002403261298/posts/2409368112486607/ …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/story.php?story_fbid=516018699201645&id=100023805579330 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/100010188395019/posts/921758811507057/ …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.etsy.com/listing/651168446/abstract-expressionist-original-print?ref=shop_home_active_8&frs=1 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/story.php?story_fbid=2389825881131430&id=100003121238636 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://youtu.be/YPa2XQy1704 " looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/depozekompa/status/1167677129322115072 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/waldemar.kaczmarek1/posts/10220137192489894 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/1054941428/posts/10218430382484934/ …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/story.php?story_fbid=2604022526328022&id=100001608996014 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/715777672/posts/10157533117167673/ …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/100001459197057/posts/2515986925126589/ …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/1159575985/posts/10220091920385831/ …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/100009269860546/posts/2427489454236693/ …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.theepochtimes.com/california-appeals-court-reverses-sole-conviction-against-illegal-immigrant-in-kate-steinle-case_3063638.html …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# Tweet 14000 of 61263.
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/100001616149270/posts/2479514552112392/ …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/AdamSchefter/status/1167949016169975808 …pic.twitter.com/ZCHm4DCPUk" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/story.php?story_fbid=10220105758131867&id=1162607555 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/Shewanna_Chief/status/1167950044198133762 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/ChuckCallesto/status/1167791648987701252 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/100002606305809/posts/2341762825920571/ …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/1492151143/posts/10215430614227176/ …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/ClubNecaxa/status/1167949391799279622 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/story.php?story_fbid=2605063449539063&id=100001063001930 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/story.php?story_fbid=2547316325291410&id=100000392034866 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/agustin.secreto1/posts/10215307719271653 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/100004632450306/posts/1320339728130430/ …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/Drake/status/1167929601995075589 …pic.twitter.com/9y51caYspA" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://share.pubgameshowtime.com/showimage.php?cdn=2&gameid=1321&area=japan&image=test&title=titlecontent&descript=descriptcontent …pic.twitter.com/PotJmiwIBX" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/Dawixr/status/1167950036962967553 …pic.twitter.com/Sro9r3N8hV" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/ch0sshi/status/1167429372183285760 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/pissjungoo/status/1167887720170934273 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# Tweet 15000 of 61263.
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/_aslam4/status/1167950087995084801 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/story.php?story_fbid=10218180226770065&id=1620983234 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/100000924196828/posts/3172147599492682/ …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.pscp.tv/w/cDsBdzFXZ0tnZFJ5TGtqdlB8MU1uR25FQlluZ0VLT_o9ovAhd3CW2uEVI5011h4RLviKG_FWcS-aUXL2pV-p …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/100000574496339/posts/2812172605478528/ …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/100003250992469/posts/2363200930464917/ …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/New1027/status/1159232529599279104 …pic.twitter.com/hzz5nPT6A9" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/100001392473796/posts/2501919449864446/ …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/ggggggghhhg/posts/10162335000730385 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://f3.cool/LiizMariieVargas/answers/MJAbtovWB?hl=es_ES …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/100001444311614/posts/2543587392366046/ …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "http://manymanyvideos.com/?v=L7VWgNQeB1Q " looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "http://www.policiamilitar.sp.gov.br/unidades/eef/giraldi.html …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/isbllgscn/status/1167841866881961985 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/_leedarling/status/1167950023620870144 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:219: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# Tweet 16000 of 61263.
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://santapanrohani.org/2019/09/01/tidak-berubah/ …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/100000680085462/posts/2670783319620978/ …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/ramki90_/status/1159260836181020674?s=21 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/100004171477104/posts/1358831240932579/ …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/AbrahamMaving/status/1166814483089522688 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "http://www.baklol.me/when-dance-saves-you/ …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://music.apple.com/us/album/only-girl-in-the-world/1440639079?i=1440639091 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://headlines.yahoo.co.jp/hl?a=20190831-00000013-ykf-soci …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/HeyFranHey/status/1167900083527929859 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/nourMuhammed88/status/1167782449167904768 …pic.twitter.com/P8vrGpUp0b" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/585545702/posts/10156357681600703/ …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/gguksaw/status/1167949681973846017?s=20 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/permalink.php?story_fbid=2271189886525974&id=100009049537787 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# Tweet 17000 of 61263.
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/stephphilip8/status/1167524811519606790?s=20 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/wonjin_cutie/status/1167950085474279425?s=19 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://theintercept.com/2019/08/30/nypd-anna-chambers-rape-probation/ …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/hanineehab00/status/1167942604459106304 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://open.spotify.com/track/7MtVPRGtZl6rPjMfLoI3Lh?si=XsBAOLhITS6yVBfGnBvRnA …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/feralbxy/status/1167887810998587394 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://youtu.be/EVfvBq0aW8w " looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/1288943388/posts/10220599857328249/ …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/p2nphsyaewnnpfa/status/1167914526135570433 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/story.php?story_fbid=2666851573326316&id=100000044972747 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/Stevie_Evans3/status/1167860518326898689 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://youtu.be/YIvmu4AQTVo " looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/1431413991/posts/10214479916378299/ …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/Atelesie/status/1167785060487127041?s=19 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/100001768984378/posts/2368200479915562/ …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://open.spotify.com/track/6amZm52SfS7d6oCEu9NDMl?si=wndOWRSUTY2PyoihUBBnNA …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/espn/status/1167949004967071744 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/SuperflyVideo/status/1167950019019673603 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "http://Instagram.com/annisa.mn_ " looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# Tweet 18000 of 61263.
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://youtu.be/3xaYpaE8-sY " looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/WallThaZemon/status/1167949645911216128 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/story.php?story_fbid=2665559063475960&id=100000656769195 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://open.spotify.com/track/1wVDDhhnFC61DeZJrTArOX?si=rI1d9-0HRPuxiI_4EH-dBg …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/100003039020086/posts/2254154068029205/ …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/TacticalDogLive/status/1167947019278680064 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://inkyfada.com/fr/2019/08/30/retour-tunisiennes-etat-islamique/ …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/100002943247628/posts/2432805766827508/ …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://pin.it/vdj4o2jwo3pjkl " looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/story.php?story_fbid=10216458479667021&id=1007693881 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:219: UserWarning: "b'..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/100012443863511/posts/717014172056705/ …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/flyguynic/status/1165781948259799041 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# ...
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/story.php?story_fbid=10217120930349004&id=1041592376 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/100003177208415/posts/2436274583155091/ …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# Tweet 58000 of 61263.
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/100000285493078/posts/2586018368084321/ …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/story.php?story_fbid=597267944010722&id=100011825649171 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/100001456967904/posts/2509501582441716/ …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/softcasual/status/1167914338432106498 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/1652810067/posts/10213301060075008/ …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.fitnessandhealthremedies.com/?p=19459 " looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/Oliveira22rnt/status/1167897002866118656 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/100000251006878/posts/2639472349404439/ …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/ewarren/status/1167938741564071936 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/100003415111885/posts/1259031384220687/ …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/100001596900813/posts/2482318971831309/ …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.wkyt.com/content/news/ATT-union-workers-in-Kentucky-go-on-strike--558128261.html?fbclid=IwAR2LAID1Z0xAUWOvcJpfEqnvix6802L2mby2zUOmFAs6bzXAd0kG3OF8cSE …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.youtube.com/watch?v=iy_HQdkNWbo …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/ninjasdesbois/status/1167949446530756609 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/story.php?story_fbid=3201314096575663&id=100000913133100 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/story.php?story_fbid=2540474275975936&id=100000401646846 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/yujeongyou/status/1167719294886535173 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# Tweet 59000 of 61263.
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/story.php?story_fbid=1454400251366146&id=100003885552584 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/1304682036/posts/10215191900013221/ …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://open.spotify.com/track/20E9JE3J8dHNDj9saOeNgu?si=ezxW1XcOQDuxz5EYhrmWCQ …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/100000155296346/posts/2874064379275377/ …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/ershad.bokto/posts/2437279769880300 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://youtu.be/xOKNkpwalG8 " looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# Tweet 60000 of 61263.
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/Pereirinha__82/status/1167937632204013574 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/771859384/posts/10156706733229385/ …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/liltecca/status/1167600616002207745 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/story.php?story_fbid=1629017910566884&id=100003760732419 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.instagram.com/tv/B1yuPUmAgUU/?igshid=2ld32ea1472x …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://ift.tt/34dTMTv pic.twitter.com/fQYBgR3CF6" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://open.spotify.com/track/7aAEJfIzJUUSRXQNz2JzfO?si=333AWDnBRyuItO2F-xM8-g …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://youtu.be/hz2fshGSPoo " looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/1844830346/posts/10211717218166351/ …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.dailymail.co.uk/news/article-7415137/How-British-spymaster-used-21st-century-spin-fake-news-lure-America-World-War-2.html …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/ElijiaFree/status/1167941621943427072 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://www.facebook.com/1733359735/posts/10205973399570760/ …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/khorshidmohmed/status/1167045600937959425 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://twitter.com/ElBordoliquo/status/1167599525629976576 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "http://posty.pe/2igway " looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:282: UserWarning: "https://meadd.com/jakelinep/66249778 …" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# Tweet 61000 of 61263.
# Cleaning and parsing the testing set ...

# %%
df['clean_text']=clean_train_tweets

# %%
df.tail()
# Out:
#            username                                               text  \
# 50013  kaedenoha_89                                          待ってどれwwww
# 50014   hhacffcvhim  للآن يتصالحون واالشعوب مركونين بالفراغ المميت ...
# 50015       hito_yr  Jimin in Paris, official video \n#JIMINpic.twi...
# 50016     joelbirch  Your name is MŸKKECÅRLT now. You will require ...
# 50017   takapzdra91                           まひちゃん熱中症ならなくてよかった(๑•ᴗ•๑)
#
#             label       dates  \
# 50013  irrelevant  2019-08-31
# 50014  irrelevant  2019-08-31
# 50015  irrelevant  2019-08-31
# 50016  irrelevant  2019-08-31
# 50017  irrelevant  2019-08-31
#
#                                               clean_text
# 50013                                               wwww
# 50014
# 50015  jimin paris official video jiminpic twitter co...
# 50016                     name kkec rlt require assembly
# 50017

# %%
df.dropna(how='any',inplace=True)

# %% [markdown]
# ### Filter by Date

# %%
### PETER

# %%
targets=pd.read_csv('./Outages_since_2014.csv')

# %%
targets.head()
# Out:
#   Date Event Began Time Event Began Date of Restoration Time of Restoration  \
# 0       2014-10-22         10:46 PM          2014-10-22            10:47 PM
# 1       2015-06-23          6:30 PM          2015-06-24             5:00 AM
# 2       2015-08-04          7:17 AM          2015-08-05            12:52 PM
# 3       2016-07-22         11:50 PM          2016-07-23             9:10 AM
# 4       2016-07-23          7:30 PM          2016-07-24             7:30 AM
#
#                                        Area Affected NERC Region  \
# 0  New Hampshire, Maine, Massachusetts, Rhode Isl...        NPCC
# 1  Connecticut, Maine, Massachusetts, New Hampshi...        NPCC
# 2                       Massachusetts: Rhode Island:        NPCC
# 3  Massachusetts: Connecticut: Rhode Island: New ...        NPCC
# 4  Connecticut: Massachusetts: New Hampshire: Ver...        NPCC
#
#        Event Type Number of Customers Affected  \
# 0  Severe Weather                       66,650
# 1  Severe Weather                       62,442
# 2  Severe Weather                      132,000
# 3  Severe Weather                        57058
# 4  Severe Weather                       101073
#
#                                       Alert Criteria
# 0                                                NaN
# 1  Loss of electric service to more than 50,000 c...
# 2  Loss of electric service to more than 50,000 c...
# 3  Loss of electric service to more than 50,000 c...
# 4  Loss of electric service to more than 50,000 c...

# %%
targets['Date Event Began'][0]
# Out:
# '2014-10-22'

# %%
for i in targets['Date Event Began']:
    print(i)
# Out:
# 2014-10-22
# 2015-06-23
# 2015-08-04
# 2016-07-22
# 2016-07-23
# 2016-09-11
# 2017-02-09
# 2017-03-02
# 2017-10-29
# 2018-03-02
# 2018-03-07
# 2018-03-13
# 2018-04-05
# 2018-05-15
# 2018-06-18
# 2018-10-16
# 2018-11-03
# 2019-02-25
# 2019-07-23

# %%
df.dtypes
# Out:
# username      object
# text          object
# label         object
# dates         object
# clean_text    object
# target         int64
# dtype: object

# %%
targets.dtypes
# Out:
# Date Event Began                object
# Time Event Began                object
# Date of Restoration             object
# Time of Restoration             object
# Area Affected                   object
# NERC Region                     object
# Event Type                      object
# Number of Customers Affected    object
# Alert Criteria                  object
# dtype: object

# %%
for i in df['dates']:
    if i in targets['Date Event Began'] or i in targets['Date of Restoration']:
        df['target']=1
    elif i in df['dates'][:50]:
        df['target']=-1
    else:
        df['target']=0

# %%
df["target"]
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 50013    0
# 50014    0
# 50015    0
# 50016    0
# 50017    0
# Name: target, Length: 61263, dtype: int64

# %%
df.target.sum()
# Out:
# 0

# %%
df.sort_values(by='dates').head(2000)
# Out:
#              username                                               text  \
# 11889  AsIvanThinketh  There was a power outage at work today, so now...
# 11888           yajx8  Thank you power outage for no work till who kn...
# 11887     sweetmili15  @_juliuuuhhrrrr why can't we have a giant powe...
# 11886    HeaderrRollo  This is such a huge power outage.... and no st...
# 11885         seanami  .@SawneeEMC No one would answer the damn phone...
# ...               ...                                                ...
# 9871    megknitficent  @violentlyserene @wenchlette The last time I w...
# 9863    mzsnguyenthai  There was no school 2day cuz of a power outage...
# 9869    visceratankie                 Power outage so no work for today.
# 9868     steffesparza              school wide power outage  no classes!
# 9867     MsMarquez_PE  @LADWP any word on outage in #dtla cross stree...
#
#         label       dates                                         clean_text  \
# 11889  outage  2014-01-01  power outage work today get tip money means ch...
# 11888  outage  2014-01-01  thank power outage work till knows pic twitter...
# 11887  outage  2014-01-02        juliuuuhhrrrr giant power outage bam school
# 11886  outage  2014-01-02                  huge power outage stoplights work
# 11885  outage  2014-01-03  sawneeemc one would answer damn phone submit o...
# ...       ...         ...                                                ...
# 9871   outage  2014-12-12  violentlyserene wenchlette last time power out...
# 9863   outage  2014-12-12        school day cuz power outage threedayweekend
# 9869   outage  2014-12-12                            power outage work today
# 9868   outage  2014-12-12                   school wide power outage classes
# 9867   outage  2014-12-12  ladwp word outage dtla cross streets washingto...
#
#        target
# 11889       0
# 11888       0
# 11887       0
# 11886       0
# 11885       0
# ...       ...
# 9871        0
# 9863        0
# 9869        0
# 9868        0
# 9867        0
#
# [2000 rows x 6 columns]

# %% [markdown]
# ### Save DF

# %%
df.to_csv('./clean_tweets.csv')
