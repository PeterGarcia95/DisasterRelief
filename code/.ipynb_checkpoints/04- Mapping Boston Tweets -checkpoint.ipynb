# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import shapely
import matplotlib.pyplot as plt
import matplotlib

# %%
geo_df = gpd.read_file("../datasets/ZIP_Codes/ZIP_Codes.shp").to_crs(epsg=4326)

# %%
geo_df.head()
# Out:
#    OBJECTID   ZIP5    ShapeSTAre    ShapeSTLen  \
# 0         1  02134  3.721936e+07  40794.182396
# 1         2  02125  6.476052e+07  62224.521440
# 2         3  02110  6.637284e+06  18358.213496
# 3         4  02118  3.116158e+07  32353.407618
# 4         5  02126  6.078585e+07  45488.394711
#
#                                             geometry
# 0  POLYGON ((-71.12340 42.36421, -71.12332 42.363...
# 1  POLYGON ((-71.04541 42.32381, -71.04472 42.323...
# 2  POLYGON ((-71.05109 42.36418, -71.04960 42.364...
# 3  POLYGON ((-71.06315 42.34689, -71.06304 42.346...
# 4  POLYGON ((-71.09670 42.29095, -71.09641 42.290...

# %%
geo_df.dtypes
# Out:
# OBJECTID         int64
# ZIP5            object
# ShapeSTAre     float64
# ShapeSTLen     float64
# geometry      geometry
# dtype: object

# %%
fig, ax = plt.subplots(figsize = (10, 10))
geo_df.plot(ax = ax);
ax.set_title('Boston Zipcodes', fontsize = 20);

# %%
clean_tweets_df = pd.read_csv('../datasets/tweets_and_preds.csv')
clean_tweets_df
# Out:
#       Unnamed: 0  index        username  \
# 0              0      0  Amithridya1001
# 1              1      1     ellensweeps
# 2              2      2         CoxHelp
# 3              3      3    Steven_McKie
# 4              4      4         Larapic
# ...          ...    ...             ...
# 1256        1256   1486   Abraham_lugol
# 1257        1257   1487    infidusfiles
# 1258        1258   1488       tikieDoll
# 1259        1259   1489     DanLHughes1
# 1260        1260   1490        SandyAlz
#
#                                                    text       label  \
# 0     No update or action on supply issue at near 2 ...      outage
# 1     I live in what is considered the largest conce...      outage
# 2     No, there is not an outage and your modem is r...      outage
# 3     No big deal @Xfinity I didn’t have to work tod...      outage
# 4     So we filled the Adpt with post-its today and ...      outage
# ...                                                 ...         ...
# 1256                                           Vas mija  irrelevant
# 1257  @VerizonSupport no I don't. And there isn't a ...      outage
# 1258        No work because of a power outage ...sweet       outage
# 1259  “Either you run the day or the day runs you.” ...  irrelevant
# 1260  http://Amazon.com : Mike & Me: The New Alzheim...  irrelevant
#
#            dates                                         clean_text  target  \
# 0     2019-07-23  update action supply issue near still even cus...       1
# 1     2019-07-23  live considered largest concentrated outage ma...       1
# 2     2019-07-23  outage modem receiving signal us reset modem f...       1
# 3     2019-07-23  big deal xfinity work today anything outage ni...       1
# 4     2019-07-23  filled adpt post today second outage ended dis...       1
# ...          ...                                                ...     ...
# 1256  2019-08-31                                           vas mija       0
# 1257  2014-06-04  verizonsupport power outage home phone fios in...       0
# 1258  2014-04-22                            work power outage sweet       0
# 1259  2019-08-31  either run day day runs officialjimrohn leader...       0
# 1260  2019-08-31  http amazon com mike new alzheimer dementia ho...       0
#
#             lat       long   zip  preds origin  index.1
# 0     42.351035 -71.157572  2132      1  train      165
# 1     42.375944 -71.077229  2121      1  train      322
# 2     42.361009 -71.062632  2135      0  train      883
# 3     42.332771 -71.088215  2119      0  train     1326
# 4     42.348956 -71.200824  2215      1  train      376
# ...         ...        ...   ...    ...    ...      ...
# 1256  42.370052 -71.134547  2163      1   test       72
# 1257  42.363169 -71.081547  2122      1   test      384
# 1258  42.270832 -71.137587  2215      1   test      137
# 1259  42.315033 -70.995205  2151      0   test     1348
# 1260  42.316065 -71.107109  2132      1   test      728
#
# [1261 rows x 14 columns]

# %%
preds = pd.read_csv('../datasets/preds_index.csv')
preds
# Out:
#      Unnamed: 0  0 origin  index
# 0             0  1   test    329
# 1             1  0   test   1072
# 2             2  0   test    698
# 3             3  0   test    630
# 4             4  1   test   1445
# ..          ... ..    ...    ...
# 374         374  1   test     72
# 375         375  1   test    384
# 376         376  1   test    137
# 377         377  0   test   1348
# 378         378  1   test    728
#
# [379 rows x 4 columns]

# %%
index_to_check = set(preds["index"])

# %%
clean_tweets_df[clean_tweets_df["Unnamed: 0"] == 1489]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, index, username, text, label, dates, clean_text, target, lat, long, zip, preds, origin, index.1]
# Index: []

# %%
accuracy_map = pd.merge( left = clean_tweets_df, right=preds, left_on = "Unnamed: 0", right_on= "index" )

# %%
clean_tweets_df.drop( columns= "Unnamed: 0", axis = 1 , inplace = True)

# %%
clean_tweets_df.head()
# Out:
#    index        username                                               text  \
# 0      0  Amithridya1001  No update or action on supply issue at near 2 ...
# 1      1     ellensweeps  I live in what is considered the largest conce...
# 2      2         CoxHelp  No, there is not an outage and your modem is r...
# 3      3    Steven_McKie  No big deal @Xfinity I didn’t have to work tod...
# 4      4         Larapic  So we filled the Adpt with post-its today and ...
#
#     label       dates                                         clean_text  \
# 0  outage  2019-07-23  update action supply issue near still even cus...
# 1  outage  2019-07-23  live considered largest concentrated outage ma...
# 2  outage  2019-07-23  outage modem receiving signal us reset modem f...
# 3  outage  2019-07-23  big deal xfinity work today anything outage ni...
# 4  outage  2019-07-23  filled adpt post today second outage ended dis...
#
#    target        lat       long   zip  preds origin  index.1
# 0       1  42.351035 -71.157572  2132      1  train      165
# 1       1  42.375944 -71.077229  2121      1  train      322
# 2       1  42.361009 -71.062632  2135      0  train      883
# 3       1  42.332771 -71.088215  2119      0  train     1326
# 4       1  42.348956 -71.200824  2215      1  train      376

# %%
accuracy_df = clean_tweets_df[["target", "preds", "origin"]]
accuracy_df
# Out:
#       target  preds origin
# 0          1      1  train
# 1          1      1  train
# 2          1      0  train
# 3          1      0  train
# 4          1      1  train
# ...      ...    ...    ...
# 1256       0      1   test
# 1257       0      1   test
# 1258       0      1   test
# 1259       0      0   test
# 1260       0      1   test
#
# [1261 rows x 3 columns]

# %%
accuracy_map["correct"] = ['True' if accuracy_map.loc[i, 'target'] == accuracy_map.loc[i, 'preds'] else 'False' for i in accuracy_map.index]

# %%
accuracy_map
# Out:
#      Unnamed: 0_x  index_x        username  \
# 0               0        0  Amithridya1001
# 1               2        2         CoxHelp
# 2               4        4         Larapic
# 3               6        6      essiemay83
# 4               7        7    PSEGdelivers
# ..            ...      ...             ...
# 321          1238     1464  MiguelPoodoske
# 322          1245     1471  HazardProtocol
# 323          1246     1474      sprintcare
# 324          1250     1480        TOKYOMX1
# 325          1256     1486   Abraham_lugol
#
#                                                   text       label  \
# 0    No update or action on supply issue at near 2 ...      outage
# 1    No, there is not an outage and your modem is r...      outage
# 2    So we filled the Adpt with post-its today and ...      outage
# 3    Yesterday’s storm gave way to a power outage a...      outage
# 4    We can assure you that no power passes through...      outage
# ..                                                 ...         ...
# 321                         pic.twitter.com/B4TgkBHxsZ  irrelevant
# 322  Again, the needs to urban areas and the needs ...  irrelevant
# 323  @jacob_austria There is no current estimate ti...      outage
# 324  [TX1310] 19/9/1(日) 09:00~09:30 フジテレビ ゲゲゲの鬼太郎【唐...  irrelevant
# 325                                           Vas mija  irrelevant
#
#           dates                                         clean_text  target  \
# 0    2019-07-23  update action supply issue near still even cus...       1
# 1    2019-07-23  outage modem receiving signal us reset modem f...       1
# 2    2019-07-23  filled adpt post today second outage ended dis...       1
# 3    2019-07-23  yesterday storm gave way power outage half sto...       1
# 4    2019-07-23  assure power passes meter outage would charged...       1
# ..          ...                                                ...     ...
# 321  2019-08-31                         pic twitter com b tgkbhxsz       0
# 322  2019-08-31             needs urban areas needs suburban areas       0
# 323  2015-03-26  jacob austria current estimate time repair wor...       0
# 324  2019-08-31                                                 tx       0
# 325  2019-08-31                                           vas mija       0
#
#            lat       long   zip  preds origin_x  index.1  Unnamed: 0_y  0  \
# 0    42.351035 -71.157572  2132      1    train      165           254  1
# 1    42.361009 -71.062632  2135      0    train      883           362  1
# 2    42.348956 -71.200824  2215      1    train      376           135  1
# 3    42.283963 -71.053019  2131      1    train      289           243  1
# 4    42.366414 -71.074898  2130      0    train      702           206  1
# ..         ...        ...   ...    ...      ...      ...           ... ..
# 321  42.332397 -71.141188  2130      0     test     1087           181  0
# 322  42.271597 -71.025388  2115      1     test     1237           257  0
# 323  42.310198 -71.157988  2119      1     test      731           346  1
# 324  42.364121 -71.024203  2134      1     test      554           207  1
# 325  42.370052 -71.134547  2163      1     test       72            42  1
#
#     origin_y  index_y correct
# 0       test        0    True
# 1       test        2   False
# 2       test        4    True
# 3       test        6    True
# 4       test        7   False
# ..       ...      ...     ...
# 321     test     1238    True
# 322     test     1245   False
# 323     test     1246   False
# 324     test     1250   False
# 325     test     1256   False
#
# [326 rows x 19 columns]

# %%
accuracy_df["col"] = ['True Prediction' if accuracy_df.loc[i, 'target'] == accuracy_df.loc[i, 'preds'] else 'False Prediction' for i in accuracy_df.index]
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
accuracy_df
# Out:
#       target  preds origin               col
# 0          1      1  train   True Prediction
# 1          1      1  train   True Prediction
# 2          1      0  train  False Prediction
# 3          1      0  train  False Prediction
# 4          1      1  train   True Prediction
# ...      ...    ...    ...               ...
# 1256       0      1   test  False Prediction
# 1257       0      1   test  False Prediction
# 1258       0      1   test  False Prediction
# 1259       0      0   test   True Prediction
# 1260       0      1   test  False Prediction
#
# [1261 rows x 4 columns]

# %%
accuracy_gdf = gpd.GeoDataFrame(accuracy_map, 
                            geometry=gpd.points_from_xy(accuracy_map.long, 
                                                        accuracy_map.lat))

# %%
accuracy_gdf
# Out:
#      Unnamed: 0_x  index_x        username  \
# 0               0        0  Amithridya1001
# 1               2        2         CoxHelp
# 2               4        4         Larapic
# 3               6        6      essiemay83
# 4               7        7    PSEGdelivers
# ..            ...      ...             ...
# 321          1238     1464  MiguelPoodoske
# 322          1245     1471  HazardProtocol
# 323          1246     1474      sprintcare
# 324          1250     1480        TOKYOMX1
# 325          1256     1486   Abraham_lugol
#
#                                                   text       label  \
# 0    No update or action on supply issue at near 2 ...      outage
# 1    No, there is not an outage and your modem is r...      outage
# 2    So we filled the Adpt with post-its today and ...      outage
# 3    Yesterday’s storm gave way to a power outage a...      outage
# 4    We can assure you that no power passes through...      outage
# ..                                                 ...         ...
# 321                         pic.twitter.com/B4TgkBHxsZ  irrelevant
# 322  Again, the needs to urban areas and the needs ...  irrelevant
# 323  @jacob_austria There is no current estimate ti...      outage
# 324  [TX1310] 19/9/1(日) 09:00~09:30 フジテレビ ゲゲゲの鬼太郎【唐...  irrelevant
# 325                                           Vas mija  irrelevant
#
#           dates                                         clean_text  target  \
# 0    2019-07-23  update action supply issue near still even cus...       1
# 1    2019-07-23  outage modem receiving signal us reset modem f...       1
# 2    2019-07-23  filled adpt post today second outage ended dis...       1
# 3    2019-07-23  yesterday storm gave way power outage half sto...       1
# 4    2019-07-23  assure power passes meter outage would charged...       1
# ..          ...                                                ...     ...
# 321  2019-08-31                         pic twitter com b tgkbhxsz       0
# 322  2019-08-31             needs urban areas needs suburban areas       0
# 323  2015-03-26  jacob austria current estimate time repair wor...       0
# 324  2019-08-31                                                 tx       0
# 325  2019-08-31                                           vas mija       0
#
#            lat       long   zip  preds origin_x  index.1  Unnamed: 0_y  0  \
# 0    42.351035 -71.157572  2132      1    train      165           254  1
# 1    42.361009 -71.062632  2135      0    train      883           362  1
# 2    42.348956 -71.200824  2215      1    train      376           135  1
# 3    42.283963 -71.053019  2131      1    train      289           243  1
# 4    42.366414 -71.074898  2130      0    train      702           206  1
# ..         ...        ...   ...    ...      ...      ...           ... ..
# 321  42.332397 -71.141188  2130      0     test     1087           181  0
# 322  42.271597 -71.025388  2115      1     test     1237           257  0
# 323  42.310198 -71.157988  2119      1     test      731           346  1
# 324  42.364121 -71.024203  2134      1     test      554           207  1
# 325  42.370052 -71.134547  2163      1     test       72            42  1
#
#     origin_y  index_y correct                    geometry
# 0       test        0    True  POINT (-71.15757 42.35104)
# 1       test        2   False  POINT (-71.06263 42.36101)
# 2       test        4    True  POINT (-71.20082 42.34896)
# 3       test        6    True  POINT (-71.05302 42.28396)
# 4       test        7   False  POINT (-71.07490 42.36641)
# ..       ...      ...     ...                         ...
# 321     test     1238    True  POINT (-71.14119 42.33240)
# 322     test     1245   False  POINT (-71.02539 42.27160)
# 323     test     1246   False  POINT (-71.15799 42.31020)
# 324     test     1250   False  POINT (-71.02420 42.36412)
# 325     test     1256   False  POINT (-71.13455 42.37005)
#
# [326 rows x 20 columns]

# %%
clean_gdf = gpd.GeoDataFrame(clean_tweets_df, 
                            geometry=gpd.points_from_xy(clean_tweets_df.long, 
                                                        clean_tweets_df.lat))

# %%
clean_gdf.head()
# Out:
#    index        username                                               text  \
# 0      0  Amithridya1001  No update or action on supply issue at near 2 ...
# 1      1     ellensweeps  I live in what is considered the largest conce...
# 2      2         CoxHelp  No, there is not an outage and your modem is r...
# 3      3    Steven_McKie  No big deal @Xfinity I didn’t have to work tod...
# 4      4         Larapic  So we filled the Adpt with post-its today and ...
#
#     label       dates                                         clean_text  \
# 0  outage  2019-07-23  update action supply issue near still even cus...
# 1  outage  2019-07-23  live considered largest concentrated outage ma...
# 2  outage  2019-07-23  outage modem receiving signal us reset modem f...
# 3  outage  2019-07-23  big deal xfinity work today anything outage ni...
# 4  outage  2019-07-23  filled adpt post today second outage ended dis...
#
#    target        lat       long   zip  preds origin  index.1  \
# 0       1  42.351035 -71.157572  2132      1  train      165
# 1       1  42.375944 -71.077229  2121      1  train      322
# 2       1  42.361009 -71.062632  2135      0  train      883
# 3       1  42.332771 -71.088215  2119      0  train     1326
# 4       1  42.348956 -71.200824  2215      1  train      376
#
#                      geometry
# 0  POINT (-71.15757 42.35104)
# 1  POINT (-71.07723 42.37594)
# 2  POINT (-71.06263 42.36101)
# 3  POINT (-71.08822 42.33277)
# 4  POINT (-71.20082 42.34896)

# %%
clean_gdf.plot(figsize = (20,20));
plt.title('Tweets in Boston', fontsize = 20);
plt.xlabel('Longitude', fontsize = 10);
plt.ylabel('Latitude', fontsize = 10);

# %%
clean_pred = accuracy_gdf[accuracy_gdf['geometry'].within(geo_df['geometry'].unary_union)]
# only keep those points within polygons
boston_points = clean_gdf[clean_gdf['geometry'].within(geo_df['geometry'].unary_union)]

# %%
color_dict = {1: 'Outage',0:'Not Outage'}
color_map = {1: 'Outage',0:'Not Outage'}
clean_pred["color"] = clean_pred["target"].map(color_map)
boston_points['color'] = boston_points['target'].map(color_dict)
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
fig, ax = plt.subplots(figsize = (20,20))
geo_df.plot(ax = ax, facecolor = 'aliceblue', edgecolor = 'indigo');
clean_gdf.plot(ax = ax);
ax.set_title('Tweets in Boston', fontsize = 20)
ax.set_facecolor('grey')
ax.set_xlabel('Longitude', fontsize = 16);
ax.set_ylabel('Latitude', fontsize = 16);

# %%
fig, ax = plt.subplots(figsize = (20,20))
geo_df.plot(ax = ax, facecolor = 'cornsilk', edgecolor = 'grey');
boston_points.plot(ax = ax,
                   #c = boston_points['color'],
                   column = 'color',
                   cmap = matplotlib.colors.ListedColormap(['navy','red']),
                   categorical = True,
                   #color = boston_points['color'],
                   legend = True, edgecolor = 'w', 
                   legend_kwds={ 'fontsize': 30, 'loc' : 'lower right'}, markersize = 70 );
ax.set_title('Tweets in Boston Per Zip Code', fontsize = 40)
ax.set_facecolor('white')
ax.set_xlabel('Longitude', fontsize = 35);
ax.set_ylabel('Latitude', fontsize = 35);
plt.xticks(fontsize=15);
plt.yticks(fontsize= 15);

#ax.legend(["Tweets Indicating a Blackout"] , fontsize = 20, loc = 'upper left');

# %%
fig, ax = plt.subplots(figsize = (20,20))
geo_df.plot(ax = ax, facecolor = 'cornsilk', edgecolor = 'grey');
clean_pred.plot(ax = ax,
                   #c = boston_points['color'],
                   column = 'correct',
                   cmap = matplotlib.colors.ListedColormap(['navy','red']),
                   categorical = True,
                   #color = boston_points['color'],
                   legend = True, edgecolor = 'w', 
                   legend_kwds={ 'fontsize': 30, 'loc' : 'lower right'}, markersize = 300 , marker = '*');
ax.set_title('Prediction Accuracy', fontsize = 40)
ax.set_facecolor('white')
ax.set_xlabel('Longitude', fontsize = 35);
ax.set_ylabel('Latitude', fontsize = 35);
plt.xticks(fontsize=15);
plt.yticks(fontsize= 15);
