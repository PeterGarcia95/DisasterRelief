# %%
import pandas as pd

# %% [markdown]
# Power Outages 2017

# %%
outages_2017 = pd.read_csv('../datasets/raw_data/2017_Annual_Summary.csv')

# %%
outages_2017
# Out:
#         Month Date Event Began Time Event Began Date of Restoration  \
# 0    January        01/05/2017          4:56 PM          01/05/2017
# 1    January        01/08/2017          9:07 AM          01/13/2017
# 2    January        01/08/2017         11:59 PM             Unknown
# 3    January        01/10/2017          7:30 PM          01/13/2017
# 4    January        01/15/2017          6:35 AM          01/15/2017
# ..        ...              ...              ...                 ...
# 186       NaN              NaN              NaN                 NaN
# 187       NaN              NaN              NaN                 NaN
# 188       NaN              NaN              NaN                 NaN
# 189       NaN              NaN              NaN                 NaN
# 190       NaN              NaN              NaN                 NaN
#
#     Time of Restoration                    Area Affected NERC Region  \
# 0               4:57 PM          Florida: Martin County;        FRCC
# ...

# %%
outages_2017.shape
# Out:
# (191, 15)

# %%
outages_2017.drop(columns= ["Unnamed: 11", "Unnamed: 12", "Unnamed: 13", "Unnamed: 14"], inplace = True)

# %%
outages_2017.shape
# Out:
# (191, 11)

# %%
outages_2017.dropna(how = 'all', inplace = True)

# %%
outages_2017 = outages_2017[(outages_2017["Event Type"] == "Severe Weather") & (outages_2017["Area Affected"].str.contains("aine")) ]

# %%
outages_2017
# Out:
#        Month Date Event Began Time Event Began Date of Restoration  \
# 22     March       03/02/2017         12:20 PM          03/02/2017
# 30     March       03/14/2017         12:32 PM             Unknown
# 126  October       10/29/2017         11:40 PM          11/01/2017
#
#     Time of Restoration                                      Area Affected  \
# 22             11:45 PM  Connecticut: Maine: Massachusetts: New Hampshi...
# 30              Unknown  Connecticut: Massachusetts: Rhode Island: New ...
# 126             6:08 PM  Connecticut: Massachusetts: New Hampshire: Mai...
#
#     NERC Region                                     Alert Criteria  \
# 22         NPCC  Loss of electric service to more than 50,000 c...
# 30         NPCC  Loss of electric service to more than 50,000 c...
# 126        NPCC  Loss of electric service to more than 50,000 c...
#
#          Event Type Demand Loss (MW) Number of Customers Affected
# ...

# %% [markdown]
# We only have tweets beginning from September 2017. We will only consider blackouts caused by severe weather after September 2017, in Maine.

# %%
outages_2017 = outages_2017[outages_2017["Month"] == "October"]
outages_2017
# Out:
#        Month Date Event Began Time Event Began Date of Restoration  \
# 126  October       10/29/2017         11:40 PM          11/01/2017
#
#     Time of Restoration                                      Area Affected  \
# 126             6:08 PM  Connecticut: Massachusetts: New Hampshire: Mai...
#
#     NERC Region                                     Alert Criteria  \
# 126        NPCC  Loss of electric service to more than 50,000 c...
#
#          Event Type Demand Loss (MW) Number of Customers Affected
# 126  Severe Weather          Unknown                       310453

# %% [markdown]
# Power Outages 2018

# %%
outages_2018 = pd.read_csv('../datasets/raw_data/2018_Annual_Summary.csv')
outages_2018
# Out:
#         Month Date Event Began Time Event Began Date of Restoration  \
# 0    January        01/01/2018          6:21 PM          01/02/2018
# 1     January       01/01/2018          5:43 PM             Unknown
# 2     January       01/01/2018          9:37 PM          01/02/2018
# 3     January       01/02/2018         10:00 AM          02/12/2018
# 4     January       01/02/2018          7:30 AM             Unknown
# ..        ...              ...              ...                 ...
# 215  December       12/26/2018          1:00 AM          01/03/2019
# 216  December       12/27/2018          9:12 PM          12/27/2018
# 217  December       12/27/2018         12:05 AM          12/27/2018
# 218  December       12/27/2018         12:50 PM          12/27/2018
# 219  December       12/30/2018         11:41 AM          12/30/2018
#
#     Time of Restoration                                      Area Affected  \
# ...

# %%
outages_2018.shape
# Out:
# (220, 11)

# %%
outages_2018.dropna(how = 'all', inplace = True)

# %%
outages_2018 = outages_2018[(outages_2018["Event Type"] == "Severe Weather") & (outages_2018["Area Affected"].str.contains("aine")) ]
outages_2018
# Out:
#         Month Date Event Began Time Event Began Date of Restoration  \
# 43      March       03/07/2018          7:37 PM          03/10/2018
# 54      April       04/05/2018         12:50 AM          04/05/2018
# 67        May       05/05/2018          4:30 AM          05/05/2018
# 87       June       06/18/2018          6:20 PM          06/19/2018
# 171   October       10/16/2018          4:15 AM          10/16/2018
# 181  November       11/03/2018          5:20 PM          11/04/2018
# 194  November       11/27/2018          8:00 AM          11/28/2018
#
#     Time of Restoration                                      Area Affected  \
# 43              4:35 PM  Connecticut: Massachusetts: Maine: New Hampshi...
# 54              4:00 PM  Connecticut: Maine: Massachusetts: New Hampshi...
# 67              3:30 PM                     Vermont: New Hampshire: Maine:
# 87             12:15 AM  Connecticut: Maine: Massachusetts: New Hampshi...
# ...

# %% [markdown]
# Power Outages 2019

# %%
outages_2019 = pd.read_csv('../datasets/raw_data/2019_Annual_Summary.csv', header = 1)
outages_2019
# Out:
#         Month Date Event Began Time Event Began Date of Restoration  \
# 0    January        01/05/2019          1:19 PM          01/05/2019
# 1     January       01/06/2019          3:00 AM          01/09/2019
# 2     January       01/06/2019          5:56 PM          01/06/2019
# 3     January       01/06/2019          1:00 AM          01/06/2019
# 4     January       01/07/2019          8:57 PM          01/07/2019
# ..        ...              ...              ...                 ...
# 215       NaN              NaN              NaN                 NaN
# 216       NaN              NaN              NaN                 NaN
# 217       NaN              NaN              NaN                 NaN
# 218       NaN              NaN              NaN                 NaN
# 219       NaN              NaN              NaN                 NaN
#
#     Time of Restoration                                      Area Affected  \
# ...

# %%
outages_2019.shape
# Out:
# (220, 11)

# %%
outages_2019.dropna(how = 'all', inplace = True)

# %%
outages_2019 = outages_2019[(outages_2019["Event Type"] == "Severe Weather") & (outages_2019["Area Affected"].str.contains("aine")) ]
outages_2019
# Out:
#        Month Date Event Began Time Event Began Date of Restoration  \
# 47  February       02/25/2019          1:35 PM          02/26/2019
#
#    Time of Restoration                                      Area Affected  \
# 47             2:50 AM  Connecticut, Massachusetts, New Hampshire, Mai...
#
#    NERC Region                                     Alert Criteria  \
# 47        NPCC  Loss of electric service to more than 50,000 c...
#
#         Event Type Demand Loss (MW) Number of Customers Affected
# 47  Severe Weather          Unknown                        72332

# %%
outages_2019.shape
# Out:
# (1, 11)

# %% [markdown]
# Joining out Data

# %%
outages_2017_18 = pd.concat([outages_2017, outages_2018])

# %%
outages = pd.concat([outages_2017_18, outages_2019])

# %% [markdown]
# Let's make sure that we have the time in DateTime format

# %%
outages.loc[:,"Date Event Began"] = pd.to_datetime(outages["Date Event Began"])

# %%
outages.loc[:,"Date of Restoration"] = pd.to_datetime(outages["Date of Restoration"])

# %%
outages
# Out:
#         Month Date Event Began Time Event Began Date of Restoration  \
# 126   October       2017-10-29         11:40 PM          2017-11-01
# 43      March       2018-03-07          7:37 PM          2018-03-10
# 54      April       2018-04-05         12:50 AM          2018-04-05
# 67        May       2018-05-05          4:30 AM          2018-05-05
# 87       June       2018-06-18          6:20 PM          2018-06-19
# 171   October       2018-10-16          4:15 AM          2018-10-16
# 181  November       2018-11-03          5:20 PM          2018-11-04
# 194  November       2018-11-27          8:00 AM          2018-11-28
# 47   February       2019-02-25          1:35 PM          2019-02-26
#
#     Time of Restoration                                      Area Affected  \
# 126             6:08 PM  Connecticut: Massachusetts: New Hampshire: Mai...
# 43              4:35 PM  Connecticut: Massachusetts: Maine: New Hampshi...
# ...

# %%
outages.dtypes
# Out:
# Month                                   object
# Date Event Began                datetime64[ns]
# Time Event Began                        object
# Date of Restoration             datetime64[ns]
# Time of Restoration                     object
# Area Affected                           object
# NERC Region                             object
# Alert Criteria                          object
# Event Type                              object
# Demand Loss (MW)                        object
# Number of Customers Affected            object
# dtype: object

# %%
outages.to_csv("../datasets/Outages_since_2017.csv")
